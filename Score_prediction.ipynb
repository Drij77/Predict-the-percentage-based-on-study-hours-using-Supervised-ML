# %% [markdown]
# # Author : Drij Chudasama

# %% [markdown]
# # Task 2 : Predict the percentage of an student based on the no. of study hours usinh supervised machine learning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
path =  "http://bit.ly/w-data"
info = pd.read_csv(path)
info
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
info.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
info.tail()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
info.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# # Visualization of data by scatter plot

# %%
plt.xlabel('Hours',fontsize=15)
plt.ylabel('Scores',fontsize=15)
plt.title('Hours studied vs Score', fontsize=10)
plt.scatter(info.Hours,info.Scores,color='blue')
plt.show()

# %% [markdown]
# # Splitting into train and test sets n to train and test sets

# %%
X = info.iloc[:,:-1].values
Y = info.iloc[:,1].values

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state = 0,test_size=0.2)

# %%
print("X train.shape =", X_train.shape)
print("Y train.shape =", Y_train.shape)
print("X test.shape  =", X_test.shape)
print("Y test.shape  =", Y_test.shape)
# Out:
# X train.shape = (20, 1)
# Y train.shape = (20,)
# X test.shape  = (5, 1)
# Y test.shape  = (5,)

# %% [markdown]
# # Model Training

# %%
linreg=LinearRegression()
linreg.fit(X_train,Y_train)
print("B0 =",linreg.intercept_,"\nB1 =",linreg.coef_)
# Out:
# B0 = 2.018160041434683
# B1 = [9.91065648]

# %%
Y0 = linreg.intercept_ + linreg.coef_*X_train

# %%
plt.scatter(X_train,Y_train,color='blue',marker='*')
plt.plot(X_train,Y0,color='red')
plt.xlabel("Hours",fontsize=15)
plt.ylabel("Scores",fontsize=15)
plt.title("Regression line(Train set)",fontsize=10)
plt.show()

# %% [markdown]
# # Test data

# %%
Y_pred=linreg.predict(X_test)
print(Y_pred)
# Out:
# [16.88414476 33.73226078 75.357018   26.79480124 60.49103328]

# %%
Y_test
# Out:
# array([20, 27, 69, 30, 62], dtype=int64)

# %%
plt.plot(X_test,Y_pred,color='red')
plt.scatter(X_test,Y_test,color='black',marker='+')
plt.xlabel("Hours",fontsize=15)
plt.ylabel("Scores",fontsize=15)
plt.title("Regression line(Test set)",fontsize=10)
plt.show()

# %% [markdown]
# # Comparing Scores

# %%
Y_test1 = list(Y_test)
prediction=list(Y_pred)
df_compare = pd.DataFrame({ 'Actual':Y_test1,'Result':prediction})
df_compare
# Out:
#    Actual     Result
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# # Accuracy

# %%
from sklearn import metrics
metrics.r2_score(Y_test,Y_pred)
# Out:
# 0.9454906892105356

# %% [markdown]
# # Error Prediction

# %%
MSE = metrics.mean_squared_error(Y_test,Y_pred)
root_E = np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))
Abs_E = np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))
print("Mean Squared Error      = ",MSE)
print("Root Mean Squared Error = ",root_E)
print("Mean Absolute Error     = ",Abs_E)
# Out:
# Mean Squared Error      =  21.5987693072174
# Root Mean Squared Error =  4.6474476121003665
# Mean Absolute Error     =  4.6474476121003665

# %% [markdown]
# # Score prediction

# %%
Prediction_score = linreg.predict([[9.25]])
print("predicted score for a student studying 9.25 hours :",Prediction_score)
# Out:
# predicted score for a student studying 9.25 hours : [93.69173249]

# %% [markdown]
# # Conclusion : From the above score we can predict that the student who studies 9.25 hours a day  will secure score 93.691732
